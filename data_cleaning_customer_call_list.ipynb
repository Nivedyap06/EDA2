# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivedyap06/EDA2/blob/main/data_cleaning_customer_call_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_excel("/content/Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"]=df["Last_Name"].str.strip("123./")
# Out:
# <ipython-input-35-335d9ab90de6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"]=df["Last_Name"].str.strip("123./")

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('[^a-zA-Z0-9]','',regex=True)
# Out:
# <ipython-input-42-58d26bfc5689>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"]=df["Phone_Number"].str.replace('[^a-zA-Z0-9]','',regex=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins     12354554
# 1         1002       Abed        Nadir     12364397
# 2         1003     Walter        White   7066950392
# 3         1004     Dwight      Schrute     12354323
# 4         1005        Jon         Snow     87667834
# 5         1006        Ron      Swanson     30476224
# 6         1007       Jeff       Winger          nan
# 7         1008   Sherlock       Holmes     87667834
# 8         1009    Gandalf          NaN           Na
# 9         1010      Peter       Parker     12354554
# 10        1011    Samwise       Gamgee          nan
# 11        1012      Harry       Potter   7066950392
# 12        1013        Don       Draper     12354323
# 13        1014     Leslie        Knope     87667834
# 14        1015       Toby  Flenderson_     30476224
# 15        1016        Ron      Weasley     12354554
# 16        1017   Michael         Scott     12364397
# ...

# %%
df["Phone_Number"]=df["Phone_Number"].apply (lambda x:str(x))
df["Phone_Number"]=df["Phone_Number"].apply(lambda x:x[0:3] + '-'+ x[3:6] + '-' + x[6:10])
# Out:
# <ipython-input-44-55684a47ac6d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"]=df["Phone_Number"].apply (lambda x:str(x))
# <ipython-input-44-55684a47ac6d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"]=df["Phone_Number"].apply(lambda x:x[0:3] + '-'+ x[3:6] + '-' + x[6:10])

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 1         1002       Abed        Nadir    123-643-97
# 2         1003     Walter        White  706-695-0392
# 3         1004     Dwight      Schrute    123-543-23
# 4         1005        Jon         Snow    876-678-34
# 5         1006        Ron      Swanson    304-762-24
# 6         1007       Jeff       Winger         nan--
# 7         1008   Sherlock       Holmes    876-678-34
# 8         1009    Gandalf          NaN          Na--
# 9         1010      Peter       Parker    123-545-54
# 10        1011    Samwise       Gamgee         nan--
# 11        1012      Harry       Potter  706-695-0392
# 12        1013        Don       Draper    123-543-23
# 13        1014     Leslie        Knope    876-678-34
# 14        1015       Toby  Flenderson_    304-762-24
# 15        1016        Ron      Weasley    123-545-54
# 16        1017   Michael         Scott    123-643-97
# ...

# %%
df.dropna()
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   123-545-54
# 1         1002       Abed        Nadir   123-643-97
# 3         1004     Dwight      Schrute   123-543-23
# 4         1005        Jon         Snow   876-678-34
# 5         1006        Ron      Swanson   304-762-24
# 6         1007       Jeff       Winger        nan--
# 7         1008   Sherlock       Holmes   876-678-34
# 9         1010      Peter       Parker   123-545-54
# 10        1011    Samwise       Gamgee        nan--
# 12        1013        Don       Draper   123-543-23
# 13        1014     Leslie        Knope   876-678-34
# 14        1015       Toby  Flenderson_   304-762-24
# 15        1016        Ron      Weasley   123-545-54
# 16        1017   Michael         Scott   123-643-97
# 18        1019      Creed       Braton         Na--
# 19        1020     Anakin    Skywalker   876-678-34
#
# ...

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('nan--','')
df["Phone_Number"]=df["Phone_Number"].str.replace('Na--','')
# Out:
# <ipython-input-48-3012b00b6b0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"]=df["Phone_Number"].str.replace('nan--','')
# <ipython-input-48-3012b00b6b0e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"]=df["Phone_Number"].str.replace('Na--','')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 1         1002       Abed        Nadir    123-643-97
# 2         1003     Walter        White  706-695-0392
# 3         1004     Dwight      Schrute    123-543-23
# 4         1005        Jon         Snow    876-678-34
# 5         1006        Ron      Swanson    304-762-24
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes    876-678-34
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker    123-545-54
# 10        1011    Samwise       Gamgee
# 11        1012      Harry       Potter  706-695-0392
# 12        1013        Don       Draper    123-543-23
# 13        1014     Leslie        Knope    876-678-34
# 14        1015       Toby  Flenderson_    304-762-24
# 15        1016        Ron      Weasley    123-545-54
# 16        1017   Michael         Scott    123-643-97
# ...

# %%
df[["Street_Address","State","Zip_Code"]]=df["Address"].str.split(',',n=2,expand=True)
# Out:
# <ipython-input-58-6a7a14c76594>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Street_Address","State","Zip_Code"]]=df["Address"].str.split(',',n=2,expand=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 1         1002       Abed        Nadir    123-643-97
# 2         1003     Walter        White  706-695-0392
# 3         1004     Dwight      Schrute    123-543-23
# 4         1005        Jon         Snow    876-678-34
# 5         1006        Ron      Swanson    304-762-24
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes    876-678-34
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker    123-545-54
# 10        1011    Samwise       Gamgee
# 11        1012      Harry       Potter  706-695-0392
# 12        1013        Don       Draper    123-543-23
# 13        1014     Leslie        Knope    876-678-34
# 14        1015       Toby  Flenderson_    304-762-24
# 15        1016        Ron      Weasley    123-545-54
# 16        1017   Michael         Scott    123-643-97
# ...

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 1         1002       Abed        Nadir    123-643-97
# 2         1003     Walter        White  706-695-0392
# 3         1004     Dwight      Schrute    123-543-23
# 4         1005        Jon         Snow    876-678-34
# 5         1006        Ron      Swanson    304-762-24
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes    876-678-34
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker    123-545-54
# 10        1011    Samwise       Gamgee
# 11        1012      Harry       Potter  706-695-0392
# 12        1013        Don       Draper    123-543-23
# 13        1014     Leslie        Knope    876-678-34
# 14        1015       Toby  Flenderson_    304-762-24
# 15        1016        Ron      Weasley    123-545-54
# 16        1017   Michael         Scott    123-643-97
# ...

# %%
df[["Street_Address","State","Zip_Code"]]=df["Address"].str.split(',',expand=True)
df
# Out:
# <ipython-input-60-5fb702a35085>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Street_Address","State","Zip_Code"]]=df["Address"].str.split(',',expand=True)
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 1         1002       Abed        Nadir    123-643-97
# 2         1003     Walter        White  706-695-0392
# 3         1004     Dwight      Schrute    123-543-23
# 4         1005        Jon         Snow    876-678-34
# 5         1006        Ron      Swanson    304-762-24
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes    876-678-34
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker    123-545-54
# ...

# %%
df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace('Yes','Y')
df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace('No','N')
# Out:
# <ipython-input-61-4a7699d64fe1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace('Yes','Y')
# <ipython-input-61-4a7699d64fe1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace('No','N')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 1         1002       Abed        Nadir    123-643-97
# 2         1003     Walter        White  706-695-0392
# 3         1004     Dwight      Schrute    123-543-23
# 4         1005        Jon         Snow    876-678-34
# 5         1006        Ron      Swanson    304-762-24
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes    876-678-34
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker    123-545-54
# 10        1011    Samwise       Gamgee
# 11        1012      Harry       Potter  706-695-0392
# 12        1013        Don       Draper    123-543-23
# 13        1014     Leslie        Knope    876-678-34
# 14        1015       Toby  Flenderson_    304-762-24
# 15        1016        Ron      Weasley    123-545-54
# 16        1017   Michael         Scott    123-643-97
# ...

# %%
df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace('NaN','')
# Out:
# <ipython-input-66-8c32a866d260>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace('NaN','')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 1         1002       Abed        Nadir    123-643-97
# 2         1003     Walter        White  706-695-0392
# 3         1004     Dwight      Schrute    123-543-23
# 4         1005        Jon         Snow    876-678-34
# 5         1006        Ron      Swanson    304-762-24
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes    876-678-34
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker    123-545-54
# 10        1011    Samwise       Gamgee
# 11        1012      Harry       Potter  706-695-0392
# 12        1013        Don       Draper    123-543-23
# 13        1014     Leslie        Knope    876-678-34
# 14        1015       Toby  Flenderson_    304-762-24
# 15        1016        Ron      Weasley    123-545-54
# 16        1017   Michael         Scott    123-643-97
# ...

# %%
df=df.replace('N/a','')
df=df.replace('NaN','')
df=df.fillna('')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 1         1002       Abed        Nadir    123-643-97
# 2         1003     Walter        White  706-695-0392
# 3         1004     Dwight      Schrute    123-543-23
# 4         1005        Jon         Snow    876-678-34
# 5         1006        Ron      Swanson    304-762-24
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes    876-678-34
# 8         1009    Gandalf
# 9         1010      Peter       Parker    123-545-54
# 10        1011    Samwise       Gamgee
# 11        1012      Harry       Potter  706-695-0392
# 12        1013        Don       Draper    123-543-23
# 13        1014     Leslie        Knope    876-678-34
# 14        1015       Toby  Flenderson_    304-762-24
# 15        1016        Ron      Weasley    123-545-54
# 16        1017   Michael         Scott    123-643-97
# 17        1018      Clark         Kent  706-695-0392
# ...

# %%
for x in df.index:
  if df.loc[x,"Do_Not_Contact"]=='Y':
    df.drop(x,inplace=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 2         1003     Walter        White  706-695-0392
# 4         1005        Jon         Snow    876-678-34
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes    876-678-34
# 8         1009    Gandalf
# 9         1010      Peter       Parker    123-545-54
# 10        1011    Samwise       Gamgee
# 11        1012      Harry       Potter  706-695-0392
# 12        1013        Don       Draper    123-543-23
# 13        1014     Leslie        Knope    876-678-34
# 14        1015       Toby  Flenderson_    304-762-24
# 15        1016        Ron      Weasley    123-545-54
# 16        1017   Michael         Scott    123-643-97
# 17        1018      Clark         Kent  706-695-0392
# 19        1020     Anakin    Skywalker    876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
for x in df.index:
  if df.loc[x,"Phone_Number"]=='':
    df.drop(x,inplace=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 2         1003     Walter        White  706-695-0392
# 4         1005        Jon         Snow    876-678-34
# 7         1008   Sherlock       Holmes    876-678-34
# 9         1010      Peter       Parker    123-545-54
# 11        1012      Harry       Potter  706-695-0392
# 12        1013        Don       Draper    123-543-23
# 13        1014     Leslie        Knope    876-678-34
# 14        1015       Toby  Flenderson_    304-762-24
# 15        1016        Ron      Weasley    123-545-54
# 16        1017   Michael         Scott    123-643-97
# 17        1018      Clark         Kent  706-695-0392
# 19        1020     Anakin    Skywalker    876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes              N
# 2               298 Drugs Driveway               N
# ...

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    123-545-54
# 1         1003     Walter        White  706-695-0392
# 2         1005        Jon         Snow    876-678-34
# 3         1008   Sherlock       Holmes    876-678-34
# 4         1010      Peter       Parker    123-545-54
# 5         1012      Harry       Potter  706-695-0392
# 6         1013        Don       Draper    123-543-23
# 7         1014     Leslie        Knope    876-678-34
# 8         1015       Toby  Flenderson_    304-762-24
# 9         1016        Ron      Weasley    123-545-54
# 10        1017   Michael         Scott    123-643-97
# 11        1018      Clark         Kent  706-695-0392
# 12        1020     Anakin    Skywalker    876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes              N
# 1               298 Drugs Driveway               N
# ...
